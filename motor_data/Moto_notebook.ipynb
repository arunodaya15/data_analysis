# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mp

# %%
df = pd.read_csv('archive\motor_data14-2018.csv')

# %%
df.shape
# Out:
# (508499, 16)

# %%
df.head(100) #data from first
# Out:
#     SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE  \
# 0     0  08-AUG-17  07-AUG-18           08       1202      519755.22
# 1     0  08-AUG-16  07-AUG-17           08       1202      519755.22
# 2     0  08-AUG-15  07-AUG-16           08       1202      519755.22
# 3     0  08-AUG-14  07-AUG-15           08       1202      519755.22
# 4     0  08-AUG-17  07-AUG-18           08       1202     1400000.00
# ..  ...        ...        ...          ...        ...            ...
# 95    0  18-JUL-16  17-JUL-17           91       1202       30000.00
# 96    0  18-JUL-15  17-JUL-16           91       1202       30000.00
# 97    0  18-JUL-14  17-JUL-15           91       1202       30000.00
# 98    0  18-JUL-17  17-JUL-18           91       1202      120000.00
# 99    0  18-JUL-16  17-JUL-17           91       1202       52000.00
#
#      PREMIUM   OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY  \
# 0    5097.83  5000029885     2007.0        4.0                6.0
# ...

# %%
df.tail()  #data from last
# Out:
#         SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE  \
# 508494    0  02-FEB-18  01-FEB-19           12       1202            0.0
# 508495    0  02-FEB-18  01-FEB-19           12       1202            0.0
# 508496    0  02-FEB-18  01-FEB-19           12       1202            0.0
# 508497    0  02-FEB-18  01-FEB-19           12       1202            0.0
# 508498    0  02-FEB-18  01-FEB-19           12       1202            0.0
#
#         PREMIUM   OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY  \
# 508494   294.51  5001350484     2018.0        4.0                7.0
# 508495   299.51  5001350489     2018.0        4.0                7.0
# 508496   294.51  5001350498     2018.0        4.0                7.0
# 508497   294.51  5001350502     2018.0        4.0                7.0
# 508498   294.51  5001350505     2018.0        4.0                7.0
#
#        TYPE_VEHICLE  CCM_TON    MAKE      USAGE  CLAIM_PAID
# ...

# %%
df.describe()
# Out:
#                  SEX      INSR_TYPE  INSURED_VALUE       PREMIUM  \
# count  508499.000000  508499.000000   5.084990e+05  5.084860e+05
# mean        0.599960    1201.758202   5.636926e+05  7.944377e+03
# std         0.641585       0.430509   9.336250e+05  1.550939e+04
# min         0.000000    1201.000000   0.000000e+00  0.000000e+00
# 25%         0.000000    1202.000000   0.000000e+00  6.670000e+02
# 50%         1.000000    1202.000000   1.500000e+05  3.450300e+03
# 75%         1.000000    1202.000000   8.500000e+05  1.056300e+04
# max         2.000000    1204.000000   6.782439e+07  7.581230e+06
#
#           OBJECT_ID      PROD_YEAR      SEATS_NUM  CARRYING_CAPACITY  \
# count  5.084990e+05  508436.000000  508404.000000      391665.000000
# mean   5.000578e+09    2006.345605       6.100263         416.533046
# std    3.579549e+05       9.732890      13.605758        3206.744093
# min    5.000018e+09    1950.000000       0.000000           0.000000
# ...

# %%
df.columns
# Out:
# Index(['SEX', 'INSR_BEGIN', 'INSR_END', 'EFFECTIVE_YR', 'INSR_TYPE',
#        'INSURED_VALUE', 'PREMIUM', 'OBJECT_ID', 'PROD_YEAR', 'SEATS_NUM',
#        'CARRYING_CAPACITY', 'TYPE_VEHICLE', 'CCM_TON', 'MAKE', 'USAGE',
#        'CLAIM_PAID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508499 entries, 0 to 508498
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   SEX                508499 non-null  int64
#  1   INSR_BEGIN         508499 non-null  object
#  2   INSR_END           508499 non-null  object
#  3   EFFECTIVE_YR       508496 non-null  object
#  4   INSR_TYPE          508499 non-null  int64
#  5   INSURED_VALUE      508499 non-null  float64
#  6   PREMIUM            508486 non-null  float64
#  7   OBJECT_ID          508499 non-null  int64
#  8   PROD_YEAR          508436 non-null  float64
#  9   SEATS_NUM          508404 non-null  float64
#  10  CARRYING_CAPACITY  391665 non-null  float64
#  11  TYPE_VEHICLE       508499 non-null  object
#  12  CCM_TON            508493 non-null  float64
#  13  MAKE               508494 non-null  object
#  14  USAGE              508499 non-null  object
# ...

# %%
df.describe(include  = 'object')
# Out:
#        INSR_BEGIN   INSR_END EFFECTIVE_YR TYPE_VEHICLE    MAKE      USAGE
# count      508499     508499       508496       508499  508494     508499
# unique       1461       1691          139           11     746         14
# top     08-JUL-17  07-JUL-18           11  Motor-cycle  TOYOTA  Own Goods
# freq        16754      17378        90670       105977  167054     134107

# %%
for col in df.describe(include  = 'object').columns:
    print(col)
    print(df[col].unique())
# Out:
# INSR_BEGIN
# ['08-AUG-17' '08-AUG-16' '08-AUG-15' ... '12-SEP-17' '12-SEP-14'
#  '06-MAY-18']
# INSR_END
# ['07-AUG-18' '07-AUG-17' '07-AUG-16' ... '28-MAR-15' '21-JUN-15'
#  '05-MAY-19']
# EFFECTIVE_YR
# ['08' '12' '14' '17' '15' '10' '97' '72' '11' '91' '09' '80' '79' '06'
#  '05' '07' '95' '96' '94' '5/' '92' '84' '00' '03' '13' '28' '16' '04'
#  '01' '85' '82' '76' '18' '57' '27' '50' '86' '99' '81' '19' '02' '30'
#  '/A' '31' '38' '33' '89' '90' '26' '98' '83' '41' '46' '6-' '48' '40'
#  '35' '49' '67' '55' '71' '70' '52' '58' '25' '23' '75' '24' '22' '42'
#  '-7' '56' '51' '74' '61' '88' '93' '53' '66' '87' '63' '21' '73' '20'
#  '77' '7B' '78' '4B' '45' '65' '62' '54' '59' '44' '64' '37' '32' '69'
#  '39' '47' '60' '43' '68' '34' '36' '8B' '-1' '1C' '29' '5B' 'EN' '-2'
#  '-6' '-8' '-B' '0-' '-9' '/0' '1-' '1A' '2A' '6A' 'MO' 'SR' '1S' 'SS'
#  '1R' '/2' '1K' '1M' '7-' '4A' '5A' '0A' 'EA' '3A' '5C' '6B' '7A' nan]
# TYPE_VEHICLE
# ...

# %%
df.isnull().sum()
# Out:
# SEX                       0
# INSR_BEGIN                0
# INSR_END                  0
# EFFECTIVE_YR              3
# INSR_TYPE                 0
# INSURED_VALUE             0
# PREMIUM                  13
# OBJECT_ID                 0
# PROD_YEAR                63
# SEATS_NUM                95
# CARRYING_CAPACITY    116834
# TYPE_VEHICLE              0
# CCM_TON                   6
# MAKE                      5
# USAGE                     0
# CLAIM_PAID           470727
# dtype: int64

# %%
df.isnull()['CLAIM_PAID'].sum()
# Out:
# 470727

# %%
df['CLAIM_PAID'].fillna(0.00,inplace=True)
df.isnull()['CLAIM_PAID'].sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# SEX                       0
# INSR_BEGIN                0
# INSR_END                  0
# EFFECTIVE_YR              3
# INSR_TYPE                 0
# INSURED_VALUE             0
# PREMIUM                  13
# OBJECT_ID                 0
# PROD_YEAR                63
# SEATS_NUM                95
# CARRYING_CAPACITY    116834
# TYPE_VEHICLE              0
# CCM_TON                   6
# MAKE                      5
# USAGE                     0
# CLAIM_PAID                0
# dtype: int64

# %%
df['CARRYING_CAPACITY'].unique()
# Out:
# array([6.000e+00, 7.000e+00, 2.200e+02, ..., 3.260e+02, 1.151e+02,
#        1.300e+05])

# %%
df.describe().round(2)
# Out:
#              SEX  INSR_TYPE  INSURED_VALUE     PREMIUM     OBJECT_ID  \
# count  508499.00  508499.00      508499.00   508486.00  5.084990e+05
# mean        0.60    1201.76      563692.58     7944.38  5.000578e+09
# std         0.64       0.43      933624.97    15509.39  3.579549e+05
# min         0.00    1201.00           0.00        0.00  5.000018e+09
# 25%         0.00    1202.00           0.00      667.00  5.000227e+09
# 50%         1.00    1202.00      150000.00     3450.30  5.000627e+09
# 75%         1.00    1202.00      850000.00    10563.00  5.000863e+09
# max         2.00    1204.00    67824388.47  7581230.43  5.001351e+09
#
#        PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY    CCM_TON   CLAIM_PAID
# count  508436.00  508404.00          391665.00  508493.00    508499.00
# mean     2006.35       6.10             416.53    3096.95     18054.68
# std         9.73      13.61            3206.74    3411.72    301682.29
# ...

# %%
df.sort_values(by=['CARRYING_CAPACITY'],ascending = False)
# Out:
#         SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE  \
# 167792    1  25-DEC-14  24-DEC-15           12       1202      250000.00
# 167790    1  25-DEC-16  24-DEC-17           12       1202      250000.00
# 167791    1  25-DEC-15  24-DEC-16           12       1202      250000.00
# 167789    1  25-DEC-17  24-DEC-18           12       1202      250000.00
# 490537    0  15-JUN-17  14-JUN-18           13       1202     4175785.28
# ...     ...        ...        ...          ...        ...            ...
# 508461    0  01-JAN-18  31-DEC-18           78       1201       60202.50
# 508467    0  13-JAN-18  12-JAN-19           15       1201      807727.18
# 508477    0  21-JAN-18  20-JAN-19           11       1201      807727.18
# 508480    1  13-JUN-18  12-JUN-19           14       1201      480000.00
# 508489    0  01-JAN-18  31-DEC-18           78       1201       60202.50
#
#           PREMIUM   OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY  \
# ...

# %%
df['CARRYING_CAPACITY'].isnull().describe().unique()
# Out:
# array([508499, 2, False, 391665], dtype=object)

# %%
df.groupby('CARRYING_CAPACITY').count()
# Out:
#                       SEX  INSR_BEGIN  INSR_END  EFFECTIVE_YR  INSR_TYPE  \
# CARRYING_CAPACITY
# 0.00               162187      162187    162187        162186     162187
# 1.00                 5864        5864      5864          5864       5864
# 1.76                    1           1         1             1          1
# 1.92                    4           4         4             4          4
# 2.00                 1190        1190      1190          1190       1190
# ...                   ...         ...       ...           ...        ...
# 130000.00               1           1         1             1          1
# 143500.00               1           1         1             1          1
# 150000.00               2           2         2             2          2
# 160000.00               2           2         2             2          2
# 224000.00               4           4         4             4          4
#
# ...

# %%
df['vec_type'] = np.where(df['CARRYING_CAPACITY']<25000,'Light','Heavy'
                         )
df.query('vec_type=="Heavy"')
# Out:
#         SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE  \
# 36        0  08-JUL-17  07-JUL-18           97       1201      164516.00
# 37        0  08-JUL-16  07-JUL-17           97       1201      164516.00
# 38        0  08-JUL-15  07-JUL-16           97       1201      164516.00
# 39        0  08-JUL-14  07-JUL-15           97       1201      164516.00
# 46        0  08-JUL-14  07-JUL-15           97       1201      242209.00
# ...     ...        ...        ...          ...        ...            ...
# 508461    0  01-JAN-18  31-DEC-18           78       1201       60202.50
# 508467    0  13-JAN-18  12-JAN-19           15       1201      807727.18
# 508477    0  21-JAN-18  20-JAN-19           11       1201      807727.18
# 508480    1  13-JUN-18  12-JUN-19           14       1201      480000.00
# 508489    0  01-JAN-18  31-DEC-18           78       1201       60202.50
#
#          PREMIUM   OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY  \
# ...

# %%
df.dtypes['CARRYING_CAPACITY']
# Out:
# dtype('float64')
