# %%
import pandas as pd

# %%
from pivottablejs import pivot_ui

# %%
df = pd.read_csv("Sales_Transaction.csv")

# %%
df2 = df.head(100)
df2
# Out:
#    TransactionNo       Date ProductNo                          ProductName  \
# 0         581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1         581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2         581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3         581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4         581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
# ..           ...        ...       ...                                  ...
# 95        581478  12/9/2019     23503   Playing Cards Keep Calm & Carry On
# 96        581478  12/9/2019     23445                    Ice Cream Bubbles
# 97        581478  12/9/2019     23530             Wall Art Only One Person
# 98        581478  12/9/2019    84997C      Childrens Cutlery Polkadot Blue
# 99        581478  12/9/2019    84997D      Childrens Cutlery Polkadot Pink
#
#     Price  Quantity  CustomerNo         Country
# ...

# %%
pivot_ui(df2)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
